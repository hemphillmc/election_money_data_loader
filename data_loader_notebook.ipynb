# %% [markdown]
# # MungMaster Pro 32x
#
# Script to read in CSV files and export to MySQL.

# %%
#Data Ingestion & Manipulation
import pandas as pd
from sqlalchemy import create_engine

#Text manipulation
import re
import csv
import io

#Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#vector/matrix math
import numpy as np

pd.set_option('max_columns', 500)
plt.style.use('fivethirtyeight')

# %%
def importer(path, date_col='Date'):
    '''
    Reads in and formats individual CSV accordingly. Needed only for one-off purposes. 
    '''
    df = pd.read_csv(path)
    df[date_col] = pd.to_datetime(df[date_col])
    
    return df

path = '~/projects/election_money/stacyabramscampaigndec2018.csv'

campaign = importer(path)
campaign.head()

# %% [markdown]
# This is a double check to make sure we're getting the output we want.

# %%
def db_import(connection_string):
    '''
    Reads database and appends CSVs row by row.
    '''

# %%
def id_maker(df, col_name, identity_fields, base_number=1000000000):
    '''Read in DataFrame and a list of fields used to identify an entity. Assign a number to those fields.'''
    
    match_table = df[identity_fields].drop_duplicates().copy()
    match_table[col_name] = np.arange(base_number, base_number+len(match_table))
    
    df = pd.merge(df,
                  match_table,
                  on=identity_fields,
                  how='left')
    
    return df[col_name]

# %%
def jorbs(df, occupation_col):
    '''Cleans the occupations column'''
    jorbs = df.copy()
    
    jorbs[occupation_col] = jorbs[occupation_col].str.lower() #gets all jobs to the same case for proper comparison
    
    #manual mapping of job names    
    jorb_convert_map = {'not employed': ['not employed', 'retired', 'none', 'unemployed'],
                        'lawyer': ['lawyer', 'attorney', 'lawye', 'general counsel'],
                        'physician': ['doctor', 'pediatrician', 'cardio'],
                        'admin assistant': ['admin asst', 'admin coor', 'administrative assistant'],
                        'communications': ['communication'],
                        'consultant': ['consultant'],
                        'analyst': ['analyst', 'analysis'],
                        'student': ['student'],
                        'real estate': ['real estate'],
                        'education': ['education', 'university', 'teacher', 'professor', 'educator'], 
                        'data professional': ['data'],
                        'engineering': ['engineer', 'programmer', 'engineering'],
                        'sales': ['sales', 'account executive', 'regional vice president', 'business development'],
                        'marketing': ['marketing', 'event', 'social media', 'public relations', 'public affairs'],
                        'arts': ['art', 'design'],
                        'nonprofit': ['nonprofit', 'non profit', 'non-profit'],
                        'nurse': ['nurse', 'nursing'], 
                        'writer': ['writer']}
    
    #uses job mapping to assign titles to common names for better comparison purposes
    for title, jobs in jorb_convert_map.items():
        for jorb in jobs:
            jorbs.loc[jorbs[occupation_col].str.contains(jorb, na=False), occupation_col] = title
    
    return jorbs

# %%
def contributor(df, key_col='ContributorId'):
    '''Parse and prep contributor info from the database. Contributor schema:
    
    ContributorId
    LastName
    FirstName
    Address1
    Address2
    City
    State
    Zip
    PAC
    Occupation
    Employer'''
    
    campaign = df.copy() #copy dataframe so as not to impact the data in the original location
    campaign = jorbs(campaign, 'Occupation')
    
    #Prepare dataframe to use same fields as in schema
    contributor_fields = ['ContributorId', 'LastName', 'FirstName', 'Address1', 'Address2',
                          'City', 'State', 'Zip', 'PAC', 'Occupation', 'Employer']
    
    campaign[key_col] = id_maker(df=campaign, 
                                    col_name=key_col, 
                                    identity_fields=['LastName', 'FirstName', 'Address', 'Zip'])
    
    campaign['Address1'] = campaign['Address']
    campaign['Address2'] = np.nan
    
    campaign = campaign[['ContributorId', 'Type', 'LastName', 'FirstName', 'Address', 'City', 'State',
                         'Zip', 'PAC', 'Occupation', 'Employer', 'Date', 'Election', 'Election_Year', 
                         'Cash_Amount', 'In_Kind_Amount', 'In_Kind_Description', 'Candidate_FirstName', 
                         'Candidate_MiddleName', 'Candidate_LastName', 'Candidate_Suffix', 
                         'Committee_Name', 'Address1', 'Address2']]
    
    contributor = campaign[contributor_fields].drop_duplicates(subset=['ContributorId']).reset_index(drop=True)
    
    
    return (contributor, campaign)

# %%
#Builds the key to connect with MySQL Database using sqlalchemy and pandas. password can be string of choice, make sure you preserve the punctuation in each string
#file = open('getin.txt')
dialect = ''
driver = 'mysql://'
user = 'root:'
pwd = 'mungmasterpro32x'
host = '@localhost:'
port = '3306'
database = '/ElectionMoney'

key = dialect + driver + user + pwd + host + port + database

# %%
#Establish the connection using the key
engine = create_engine(key)
connection = engine.connect()

# %%
engine.table_names()
# Out:
# ['Candidate',
#  'Contribution',
#  'Contributor',
#  'CSV',
#  'Log',
#  'Office',
#  'Report',
#  'ScrapeLog']

# %%
def inception(scrape_file='ScrapeLog'):
    '''
    Grabs CSV from SQL database and appends with appropriate metadata'''
    
    #read in the table containing the scraped CSVs
    scrapelog = pd.read_sql(scrape_file, connection)
    
    #initialize a list to store each CSV
    election_master_data = []
    
    #iterate over the table grabbing the CSV for each
    for index, row in scrapelog.iterrows(): 
            
        row_csv_converter = io.StringIO(row[3]) #access the CSV string, which is in position 3 
        reader = csv.reader(row_csv_converter, delimiter=',') #Turn the string into something recognizable as a CSV

        for rows in reader:
            election_master_data.append(rows) #add these into the election master data
            
        #election_master_data.pop(0)    
    
    #define columns for the DataFrame
    cols = ['FilerID', 'Type', 'LastName', 'FirstName', 'Address', 'City',
            'State', 'Zip', 'PAC', 'Occupation', 'Employer', 'Date', 'Election',
            'Election_Year', 'Cash_Amount', 'In_Kind_Amount', 'In_Kind_Description',
            'Candidate_FirstName', 'Candidate_MiddleName', 'Candidate_LastName',
            'Candidate_Suffix', 'Committee_Name', None]
    
    #Turn consumed data into a dataframe
    df = pd.DataFrame(election_master_data)
    df = df.loc[df.loc[:, 0] != 'FilerID'].copy().reset_index(drop=True) #kill the headers that got mixed into the data (if the FilerID is 'FilerID', then it's a header)
    df.columns = cols #set dataframe columns
                
    return df

# %%
election_df = inception()

# %%
election_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54925 entries, 1 to 56420
# Data columns (total 23 columns):
# FilerID                 54925 non-null object
# Type                    54925 non-null object
# LastName                54925 non-null object
# FirstName               54925 non-null object
# Address                 54925 non-null object
# City                    54925 non-null object
# State                   54925 non-null object
# Zip                     54925 non-null object
# PAC                     54925 non-null object
# Occupation              54925 non-null object
# Employer                54925 non-null object
# Date                    54925 non-null object
# Election                54925 non-null object
# Election_Year           54925 non-null object
# Cash_Amount             54925 non-null object
# In_Kind_Amount          54925 non-null object
# In_Kind_Description     54925 non-null object
# Candidate_FirstName     54925 non-null object
# Candidate_MiddleName    54925 non-null object
# Candidate_LastName      54925 non-null object
# Candidate_Suffix        54925 non-null object
# Committee_Name          54925 non-null object
# None                    64 non-null object
# dtypes: object(23)
# memory usage: 12.6+ MB

# %%
contributors.to_sql('Contributor', connection, if_exists='append', index=False) #send the table, appending rows that already exist rather than deleting and replacing

# %%
pd.read_sql('Contributor', connection) #readout of the data from the SQL database
# Out:
#       ContributorId                                 LastName     FirstName  \
# 0        1000000000                                   Barlow       Allison
# 1        1000000001                                   Barlow         Cathy
# 2        1000000002                                   Barlow         Jesse
# 3        1000000003                                  Barnett  Elizabeth B.
# 4        1000000004                                  Barrett         Nolen
# 5        1000000005                                 Bartlett       Stephen
# 6        1000000006                                 Bartlett         Steve
# 7        1000000007                                  Barwick    William D.
# 8        1000000008                                   Baskin          Lisa
# 9        1000000009                                   Barney      Alicia W
# 10       1000000010                                   Bartel         Bruce
# 11       1000000011                                    Basto        Pamela
# 12       1000000012                                     Basu         Rajiv
# 13       1000000013                                   Bausch          John
# 14       1000000014                                   Bengel         James
# 15       1000000015                                   Benham           Ian
# 16       1000000016                                   Benson         Frank
# 17       1000000017                                   Benson      Tremayne
# 18       1000000018                                   Benson       William
# 19       1000000019                                  Bentler     Catherine
# 20       1000000020                                   Berger          Dale
# 21       1000000021                                  Bergman          Eldo
# 22       1000000022                                  Bassett       Michael
# 23       1000000023                               Bastarache         Bobby
# 24       1000000024                                    Bauer        Daniel
# 25       1000000025                                    Bauer          Dick
# 26       1000000026                                   Becker          Alan
# 27       1000000027                                Bedrosian          Sara
# 28       1000000028                                  Acheson          Hugh
# 29       1000000029                                 Achilles        Daphne
# ...             ...                                      ...           ...
# 6913     1000006913                                  Mercado         Jaime
# 6914     1000006914                                Miele Wen        Debbie
# 6915     1000006915                                Landsverk     Elizabeth
# 6916     1000006916                           McBride-Martin      Parris P
# 6917     1000006917                                  Meadows           Jim
# 6918     1000006918                                   Mehler        Ernest
# 6919     1000006919                                    Mamet          Noah
# 6920     1000006920                                   Mandel        Harlan
# 6921     1000006921                                  Riordan        Dennis
# 6922     1000006922                                   Ossoff       Richard
# 6923     1000006923                                     Otis        Brenda
# 6924     1000006924                                  Packard     Alexander
# 6925     1000006925                                 ROBINSON       HEYWARD
# 6926     1000006926                                     Reid         Cindy
# 6927     1000006927                                    Meyer          Jeff
# 6928     1000006928                             Michel-Bryan     Genevieve
# 6929     1000006929                              O???Connell     Elizabeth
# 6930     1000006930                                  Peebles          Anne
# 6931     1000006931  People for the American Way Action Fund          None
# 6932     1000006932                                 Omabegho      Jennifer
# 6933     1000006933                                     Ozer        Connie
# 6934     1000006934                                  Patrick        Angela
# 6935     1000006935                                     Pena          Jose
# 6936     1000006936                                  Rudnick         Betsy
# 6937     1000006937                                Rosenfeld       Cynthia
# 6938     1000006938                                    Patel        Mukesh
# 6939     1000006939                                Patterson    Cristale B
# 6940     1000006940                                   Parker      Kathleen
# 6941     1000006941                                     Peck     Katherine
# 6942     1000006942                              Pendergrast      Caroline
#
#                       Address1 Address2             City State         Zip  \
# 0              105 Berkeley Pl     None         Brooklyn    NY  11217-3786
# 1             6130 Ardleigh St     None     Philadelphia    PA  19138-1520
# 2               1427 S Pugh St     None    State College    PA  16801-6132
# 3          1123 Narcisco St NE     None      Albuquerque    NM  87112-6656
# 4                 346 29th Ave     None    San Francisco    CA  94121-1703
# 5     659 N Tomahawk Island Dr     None         Portland    OR  97217-7968
# 6     659 N Tomahawk Island Dr     None         Portland    OR  97217-7968
# 7              15 Vernon Rd NW     None          Atlanta    GA  30305-2963
# 8                   PO Box 314     None            Leeds    MA  01053-0314
# 9            421 E Live Oak St     None      San Gabriel    CA  91776-1519
# 10              114 Jastram St     None       Providence    RI  02908-3407
# 11         742 Palatine Ave SE     None          Atlanta    GA  30316-2445
# 12            295 Greenwich St     None         New York    NY  10007-1053
# 13           1214 Castleman Dr     None         Longview    WA  98632-4621
# 14            20 Canterbury Ct     None          Wendell    NC  27591-9713
# 15            184 W Poplar Ave     None        San Mateo    CA  94402-1152
# 16               429 Grant Ave     None           Geneva    IL  60134-1116
# 17             400 Pharr Rd NE     None          Atlanta    GA  30305-3276
# 18           105 Lexington Ave     None         New York    NY  10016-8962
# 19       302 Beverly Hill Blvd     None         Billings    MT  59101-0655
# 20               181 E 65th St     None         New York    NY  10065-6642
# 21          4838 Waynesboro Dr     None          Houston    TX  77035-3416
# 22          6264 Monticello Cv     None       Montgomery    AL  36117-2631
# 23               825 W 11th St     None           Austin    TX  78701-2052
# 24                61 Foster St     None        Cambridge    MA  02138-4750
# 25              58 Berkeley St     None       Somerville    MA  02143-1604
# 26          9411 SW Bayview Dr     None           Vashon    WA  98070-7025
# 27          192 Norwood Ave NE     None          Atlanta    GA  30317-1208
# 28              198B Boulevard     None           Athens    GA       30601
# 29           500 Waterfront Dr     None  East Providence    RI  02914-5056
# ...                        ...      ...              ...   ...         ...
# 6913         41 Stuyvesant Ave     None        Larchmont    NY  10538-2719
# 6914            168 Meadows Dr     None          Melrose    NY  12121-2923
# 6915        20 Hoods Point Way     None        San Mateo    CA  94402-4011
# 6916       102 San Salvador Ln     None         Santa Fe    NM  87501-1740
# 6917          1210 King Gap Rd     None        Highlands    NC  28741-6547
# 6918          Klingentalstr 69     None            Basel    ZZ       00000
# 6919       10866 Wilshire Blvd     None      Los Angeles    CA  90024-4300
# 6920         1519 Albemarle Rd     None         Brooklyn    NY  11226-4505
# 6921            523 Octavia St     None    San Francisco    CA  94102-4313
# 6922    590 Dutch Valley Rd NE     None          Atlanta    GA  30324-5330
# 6923          10502 Wickens Rd     None           Vienna    VA  22181-3032
# 6924          175 Middlesex Rd     None    Chestnut Hill    MA  02467-1837
# 6925         1830 White Oak Dr     None       Menlo Park    CA  94025-6129
# 6926            183 Harvard Ct     None        Henderson    NV  89074-0918
# 6927           243 Bartlett St     None    San Francisco    CA  94110-3109
# 6928         251 Kingsland Ter     None     South Orange    NJ  07079-1468
# 6929           5008 44th St NW     None       Washington    DC  20016-4037
# 6930      24811 Pearl Crest Ln     None           Spring    TX  77389-5076
# 6931           1101 15th St NW     None       Washington    DC  20005-5023
# 6932        224 Washington Ave     None         Brooklyn    NY  11205-3701
# 6933             PO Box 190767     None        Anchorage    AK  99519-0767
# 6934   10318 NW Langworthy Ter     None         Portland    OR  97229-8169
# 6935          3508 Monserat Dr     None         Edinburg    TX  78539-4369
# 6936           26 Fairfield St     None        Cambridge    MA  02140-1911
# 6937          245 Woodruff Ave     None      Los Angeles    CA  90024-2644
# 6938         2860 Cravey Dr NE     None          Atlanta    GA  30345-1420
# 6939           227 Montrose Dr     None        McDonough    GA  30253-4241
# 6940      1437 Hampton Glen Ct     None          Decatur    GA  30033-2020
# 6941         1615 Varnum St NW     None       Washington    DC  20011-4205
# 6942        2418 Lively Trl NE     None          Atlanta    GA  30345-3837
#
#        PAC                                         Occupation  \
# 0     None                                   Program Director
# 1     None                                           Attorney
# 2     None                                          Professor
# 3     None                                       Not employed
# 4     None                                       Not Employed
# 5     None                                             writer
# 6     None                                             writer
# 7     None                                            Partner
# 8     None                                          Historian
# 9     None                                    Human Resources
# 10    None                                           Engineer
# 11    None                              Information Requested
# 12    None                                            Partner
# 13    None                                       Not Employed
# 14    None                         IT Applications programmer
# 15    None                                       not employed
# 16    None                                       Not Employed
# 17    None                                       Not Employed
# 18    None                                       Psychologist
# 19    None                                         Consultant
# 20    None                                       Not Employed
# 21    None  run non-profit that teaches reading to childre...
# 22    None                                       Not Employed
# 23    None                                           Director
# 24    None                                          Physician
# 25    None                                           Attorney
# 26    None                                     actor/director
# 27    None                             Health Comm Specialist
# 28    None                                               chef
# 29    None                                       Not employed
# ...    ...                                                ...
# 6913  None                                           Attorney
# 6914  None                                            Retired
# 6915  None                                                 MD
# 6916  None                                 Personal assistant
# 6917  None                                       Not employed
# 6918  None                                               none
# 6919  None                                         Consultant
# 6920  None                                 Non-profit manager
# 6921  None                                           attorney
# 6922  None                                          Executive
# 6923  None                                            Retired
# 6924  None                                           Excutive
# 6925  None                                          SCIENTIST
# 6926  None                                          FILMMAKER
# 6927  None                                      High tech guy
# 6928  None                           VP/Director of Broadcast
# 6929  None                                       Not Employed
# 6930  None                                       Not Employed
# 6931  None                                               None
# 6932  None                                             artist
# 6933  None                                       Not Employed
# 6934  None                                       Not Employed
# 6935  None                                          Physician
# 6936  None                                       Not employed
# 6937  None                                             Writer
# 6938  None                                Business Consultant
# 6939  None                                         Consultant
# 6940  None                                            Retired
# 6941  None                                       philanthropy
# 6942  None                                 Physical therapist
#
#                                   Employer
# 0                      Wallace Global Fund
# 1                                 FOCG LLC
# 2                               Penn State
# 3                                 noneNone
# 4                             Not Employed
# 5                                     self
# 6                            self employed
# 7                         Duane Morris LLP
# 8                            Self Employed
# 9                                    LAUSD
# 10                         BPK Engineering
# 11                   Information Requested
# 12                   Deloitte & Touche LLP
# 13                            Not Employed
# 14    State of NC/Community College System
# 15                                    none
# 16                            Not Employed
# 17                            Not Employed
# 18                      CBT/DBT Associates
# 19                            Rodan+Fields
# 20                                    None
# 21                 Family Literacy Network
# 22                                    None
# 23                                    Self
# 24              Boston Children's Hospital
# 25           Greater Boston Legal Services
# 26                 Insight America Theater
# 27                                 HHS/CDC
# 28                           Fried Pie LLC
# 29                            Not employed
# ...                                    ...
# 6913        Simpson Thacher & Bartlett LLP
# 6914                               Retired
# 6915                         Self Employed
# 6916                      George rr Martin
# 6917                                  None
# 6918                                  none
# 6919                          NMA Partners
# 6920     Media Development Investment Fund
# 6921                                  self
# 6922           Strafford Publications Inc.
# 6923                               Retired
# 6924                           Iora Health
# 6925                         SELF-EMPLOYED
# 6926                         Self Employed
# 6927                        New Relic Inc.
# 6928                      Black Enterprise
# 6929                          Not Employed
# 6930                          Not Employed
# 6931                                  None
# 6932                                  self
# 6933                          Not Employed
# 6934                                  None
# 6935                  Donna medical clinic
# 6936                          Not employed
# 6937                                  Self
# 6938                         Self-employed
# 6939                         Self Employed
# 6940                                  None
# 6941       Civic Participation Action Fund
# 6942                       Emoryhealthcare
#
# [6943 rows x 11 columns]
